# %% [markdown]
# # **Tutorial** - Topic Modeling with BERTopic
# (last updated 08-06-2021)
#
# In this tutorial we will be exploring how to use BERTopic to create topics from the well-known 20Newsgroups dataset. The most frequent use-cases and methods are discussed together with important parameters to keep a look out for.
#
#
# ## BERTopic
# BERTopic is a topic modeling technique that leverages 🤗 transformers and a custom class-based TF-IDF to create dense clusters allowing for easily interpretable topics whilst keeping important words in the topic descriptions.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# [Reference](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# # **Installing BERTopic**
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# !pip install kaleido



#now this works:

# %%
import pandas as pd
from bertopic import BERTopic
import kaleido #required
kaleido.__version__ #0.2.1
import plotly
plotly.__version__ #5.5.0
import plotly.graph_objects as go

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
meta = pd.read_csv('/content/drive/MyDrive/6000k/data.csv')
#count how many has abstract
count = 0
index = []
for i in range(len(meta)):
    #print(i)
    
    if type(meta.iloc[i, 5])== float:
        count += 1
    else:
        index.append(i)
documents = meta.iloc[index,[1,2,6]]
documents=documents.reset_index()
documents["index"] = documents.index.values

# %%
location = "Global"
for i in range(len(meta)):
  if location == "Global":
    break
  if documents.location[i] != location:
    documents = documents.drop(index = i,axis=0)
documents.shape
# Out:
# (8331, 4)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
documents.head()
# Out:
#    index                       date  \
# 0      0  2020-02-14 03:04:33+00:00
# 1      1  2020-02-04 23:21:24+00:00
# 2      2  2020-03-31 21:21:25+00:00
# 3      3  2020-03-31 21:18:46+00:00
# 4      4  2020-03-31 20:04:07+00:00
#
#                                              content  location
# 0  ★💰 WORK FROM HOME💰 ★\n I'm Looking For Stay at...  New York
# 1  LIMITED TIME! Sign Up for FREE\nEnds March 31....  New York
# 2  Catch our own Tiffany Joy Murchison @Ms_Tiffan...  New York
# 3  clocking out is near - make sure to end of you...  New York
# 4  😎 she’s so cool... #lea #leainny #stayhome #go...  New York

# %%
import re
documents.content = documents.apply(lambda row: re.sub(r"http\S+", "", row.content).lower(), 1)
documents.content = documents.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.content.split())), 1)
#documents.content = documents.apply(lambda row: " ".join(re.sub("[^a-zA-Z0-9]+", " ", row.content).split()), 1)
stop = set(stopwords.words("english"))
documents.content = documents.apply(lambda row: " ".join(filter(lambda x:x[0] not in stop, row.content.split())), 1)
# documents.content = documents.apply(lambda row: " ".join([item for item in row.content.split() if item ]),1)
print(documents.head())
tweets = documents.content.to_list()
timestamps = documents.date.to_list()
topic_model = BERTopic(verbose=True)
topics, probs = topic_model.fit_transform(tweets)
# Out:
#    index                       date  \
# 0      0  2020-02-14 03:04:33+00:00
# 1      1  2020-02-04 23:21:24+00:00
# 2      2  2020-03-31 21:21:25+00:00
# 3      3  2020-03-31 21:18:46+00:00
# 4      4  2020-03-31 20:04:07+00:00
#
#                                              content  location
# 0  ★💰 work from home💰 ★ looking for home &amp; li...  New York
# 1  limited up for free ends 31. ★💰 work from home...  New York
# 2  catch joy virtually (and literally) hanging (o...  New York
# 3  clocking near - end right. how link. 📸 #wfh #s...  New York
# 4  😎 cool... #lea #leainny #stayhome #goldenretri...  New York
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Batches:   0%|          | 0/261 [00:00<?, ?it/s]
# 2022-05-23 09:36:06,585 - BERTopic - Transformed documents to Embeddings
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 2022-05-23 09:37:05,386 - BERTopic - Reduced dimensionality
# 2022-05-23 09:37:05,718 - BERTopic - Clustered reduced embeddings

# %%
topics_over_time = topic_model.topics_over_time(tweets, topics, timestamps, nr_bins=20)
# Out:
# 20it [00:02,  9.45it/s]

# %%
a = topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=10)

a.update_layout(
    autosize=False,
    title=("Topics Over Time"+" ("+location+")"),
)
a.show()
a.write_image("/content/drive/MyDrive/6000k/nostopword/topics_over_time_"+location+'.png',format='png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7cd223a7-01c2-4331-bd51-19e6ec70c5b4" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cd223a7-01c2-4331-bd51-19e6ec70c5b4")) {                    Plotly.newPlot(                        "7cd223a7-01c2-4331-bd51-19e6ec70c5b4",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: exciting, ng, natin, rj, needycat","<b>Topic 0</b><br>Words: workingfromhome, very, for, while, with","<b>Topic 0</b><br>Words: workingfromhome, workingmom, back, when, persons","<b>Topic 0</b><br>Words: workingfromhome, holiday, sugarscrub, 4thofjuly2020, edited","<b>Topic 0</b><br>Words: workingfromhome, joy, heart, waterfall, smallnotes","<b>Topic 0</b><br>Words: brilliant, workingfromehome, desiretoinspire, drumitup, fansonly","<b>Topic 0</b><br>Words: relate, workingfromhome, employmentlaw, frenchielife, marketer","<b>Topic 0</b><br>Words: westwood, keepers, gmornin, bertie, goalkeeper","<b>Topic 0</b><br>Words: lasha, jnr, workingtogetherforsuccess, parker, peter","<b>Topic 0</b><br>Words: adayinthelife, prcareers, publicrelations, dayinthelife, fired","<b>Topic 0</b><br>Words: prework, cancels, partly, winkle, panniversary","<b>Topic 0</b><br>Words: girls, gotta, fireforce, nordic, embassies","<b>Topic 0</b><br>Words: bf, 100k, consulting, engrossed, helper","<b>Topic 0</b><br>Words: terribleservice, selfearnes, focus, affiliate, possibilities","<b>Topic 0</b><br>Words: woodbridge, honoroak, se23, grab, created","<b>Topic 0</b><br>Words: placing, gentle, lifted, block, changing","<b>Topic 0</b><br>Words: fetishization, faulty, sitstanddesk, replacement, backtotheoffice","<b>Topic 0</b><br>Words: novacation, crackkills, prime, bum, staycation","<b>Topic 0</b><br>Words: finish, nothowiplannedit, ropeskipping, levellingup, failed"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_workingfromhome_back_love_very","x":["2020-01-31T09:37:48.744000+00:00","2020-03-11T14:35:46.800000+00:00","2020-04-20T00:38:29.600000+00:00","2020-05-29T10:41:12.400000+00:00","2020-07-07T20:43:55.200000+00:00","2020-08-16T06:46:38+00:00","2020-09-24T16:49:20.800000+00:00","2020-11-03T02:52:03.600000+00:00","2020-12-12T12:54:46.400000+00:00","2021-01-20T22:57:29.200000+00:00","2021-03-01T09:00:12+00:00","2021-04-09T19:02:54.800000+00:00","2021-05-19T05:05:37.600000+00:00","2021-06-27T15:08:20.400000+00:00","2021-08-06T01:11:03.200000+00:00","2021-09-14T11:13:46+00:00","2021-10-23T21:16:28.800000+00:00","2021-12-02T07:19:11.600000+00:00","2022-01-10T17:21:54.400000+00:00"],"y":[7,179,71,23,21,13,19,11,9,15,8,8,5,5,4,6,3,3,7],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: rye, bread, brazilian, e9, cheerios","<b>Topic 2</b><br>Words: lunch, breakfast, chocolate, food, baking","<b>Topic 2</b><br>Words: lunch, breakfast, pork, homemade, chocolate","<b>Topic 2</b><br>Words: lunch, bread, fitfood, loaf, foodshare","<b>Topic 2</b><br>Words: lunch, popcorn, lunchtime, eggs, candy","<b>Topic 2</b><br>Words: lunch, far, lunchtime, artwork, surbiton","<b>Topic 2</b><br>Words: lunch, break, breakfast, onigir, earles","<b>Topic 2</b><br>Words: lunchbreak, prepare, vegetablestirfry, lunch, food","<b>Topic 2</b><br>Words: lunches, lunch, crowdpleasers, 4letter, gobbles","<b>Topic 2</b><br>Words: wendys, lunch, fruit, breaktheyll, cheesybaconmuffins","<b>Topic 2</b><br>Words: chocolate, lunch, broader, treatday, width","<b>Topic 2</b><br>Words: lunch, coldfront, stewweather, foundation, barnes","<b>Topic 2</b><br>Words: lunch, healthyfood, bikini, lunchidea, goodfood","<b>Topic 2</b><br>Words: lunch, tomatolady, gorge, wednesdayvibe, houmous","<b>Topic 2</b><br>Words: gardeningtwitter, parsley, patch, veggie, wonky","<b>Topic 2</b> ...

# %%
from gensim.test.utils import common_corpus, common_dictionary
from gensim.models.coherencemodel import CoherenceModel

len(common_dictionary)
# Out:
# 12

# %% [markdown]
# # Evaluate

# %%
a = len(topic_model.topic_names)
ll = []
for i in range(0,a-1):
    l = []
    topictmp = topic_model.get_topic(i)
    for j in topictmp:
      l.append(j[0])
    ll.append(l)
    
    # print(l)
   

# print(ll)

import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# Preprocess documents
cleaned_docs = topic_model._preprocess_text(tweets)

# Extract vectorizer and tokenizer from BERTopic
vectorizer = topic_model.vectorizer_model
tokenizer = vectorizer.build_tokenizer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names()
tokens = [tokenizer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = ll

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
coherence = coherence_model.get_coherence()
print(coherence)
# Out:
# -11.759588473339246

# %% [markdown]
# ## Human Judegement

# %%
topic_model.get_representative_docs()
# Out:
# {0: ['con being ‘arctic’ #workingfromhome',
#   'what #workingfromhome 🤣',
#   '#workingfromhome for ☀️'],
#  1: ['when boss (cat) upset with #workingfromhome',
#   'cat was riveted #wfh (he’s really enjoying wfh)',
#   'else have wfh cat problem? #catproblems #wfh'],
#  2: ['great #workingfromhome can what bake!⠀ baked banana bread 🍌 ⠀ better looks. 😊⠀ .⠀ .⠀ .⠀ .⠀ #baker #bakingfromscratch…',
#   'perks #wfh fresh from veggie patch. kale, rocket, parsley, wonky carrots. #gardeningtwitter',
#   '#workingfromhome &amp; got no prepare #lunch? 🏘 #spicevillage have got covered. enjoy 10% #order! \u2060#takeaway &amp; #delivery 🛎 𝐒𝐨𝐮𝐭𝐡𝐚𝐥𝐥 𝟎𝟐𝟎𝟖 𝟓𝟕𝟒𝟒 𝟒𝟕𝟓 𝐂𝐫𝐨𝐲𝐝𝐨𝐧 𝟎𝟐𝟎 𝟑𝟗𝟎𝟖 𝟕𝟎𝟕𝟏 𝐒𝐨𝐮𝐭𝐡𝐞𝐧𝐝 𝟎𝟏𝟕 𝟎𝟐𝟑𝟒 𝟎𝟗𝟕𝟎'],
#  3: ['perspective from helpfully lays benefits culture. but comes financial cost, employers employees. #wfh',
#   '46% respondents have place #wfh. juniors live conditions &amp; policies wfh becomes norm needs be',
#   '#wfh business while #stayhome we part flatten curve.'],
#  4: ['nostalgia comes us uncertainty &amp; bunkering glam #wfh footwear going get hush puppies #sneakers. love ‘em. #retro #nostalgia',
#   'knitting for conservation basics complete. just need pick clothes now 👗🧦👕👖a basic pattern from knit royal wedding book. . #knitting #wfh #knit #make #clothes… 📸 via',
#   '#workwear given #newnormal #wfh has undergone vast change. now classic clothes fluid fabrics for half lean forms for lower half. #tinawaliaic #imageconsultant #workfromhome'],
#  5: ['#wfh very when have hop zoom call. love new from everything here-&gt; #ltkhome #ltkworkwear #liketkit #supportblackbusiness los',
#   'getting called for wearing “all-black” #wfh zoom calls',
#   'bbc commentator holds hilarious zoom with his | hila... via #wfh #zoom 😂who’s good'],
#  6: ['#wfh update: future wifey blueberry go with coffee 🤤😋 #magnolianetwork',
#   'little #workingfromhome for from #badseed #evil #coffeetime',
#   '3: #wfh +hs. nothing like hot cup coffee but rain #washyourhamds #stayathome #flattenthecurve'],
#  7: ['by far best #remotework have far. 4 for #wfh',
#   "fab feb's here. let's roll. 🤞🏼 #wfh #remotework",
#   'remote workers can first, especially used new employees from home, check get by via #remotework #wfh'],
#  8: ['bit late with #wfh recommendation, paul “a light”, by for relaxing but productive friday have good weekend everyone!',
#   'friday night feels .... #wfh',
#   'casual #wfh friday'],
#  9: ['lockdown have highlighted value workplace flexibility - great from via #futureofwork #wfh',
#   'else finish #wfh under lockdown restrictions change from uggs nighttime',
#   'have giving hand while working from home, #410taa #lockdown #workingfromhome canonbury'],
#  10: ['#mondaymotivation grab bargain 🥳🥰🌼 #zebra #zebrastrong #socold #workingfromhome',
#   '#goodmorning #thirstythursday #thursdaymorning let’s #workingfromhome 💙🙏🏻☕️',
#   'when new email work crush 😳 #tuesdayvibe #tuesdaymotivations #wfh'],
#  11: ['#wfh', '#wfh 100%', 'nap #wfh #whatisthislife #fyrefestival'],
#  12: ['working from home hits new level .. now ! #workingfromhome',
#   'hate working from home #workingfromhome',
#   'for us working from home wanted little visual vacation. enhance experience get fan bottle water fan while watching. #mentalhealth #workingfromhome #livinginlockdown'],
#  13: ['can’t wait what little piper while working from home. 🐶💻 #westies #wfh',
#   'working from home completely new concept for have been practicing with firms freelance work. . . wfh = wtf for experience . #precovidphoto #workfromhome #wfh…',
#   'just remembered when boss questioned really had work home for week having radioactive ☢️ well look now 103 #wfh'],
#  14: ["#ai #artificialintelligence #stemcell #microchip #computing #brain #wfh #science #data #datascience #staysafe cell - 'brain chip' project led by with partners - revolutionise computing power via",
#   '#tech #technology #ar #vr #augmentedreality #ai #algorithm #innovation #reinvent #cloud #iot #5g #data #datascience #bigdata #cybersecurity #automation #cloudcomputing #algorithm #staysafe #wfh #artificialintelligence game changer !! 👇',
#   '#wednesdaythought #tech #technology #online users #cloud #cloudcomputing #5g #data #socialmedia #ai #datascience #artificiallintelligence #innovation #ml #ar #vr #startups #staysafe #iot #wfh #cyberattack #cybersecurity #apple #iphone13 history up'],
#  15: ['we for very video (sound #wfh',
#   'health benefits video cannot be people haven’t picked up when keep video video be #wfh',
#   'really just work for company forces us video bust. #wfh'],
#  16: ['high consumption with #wfh #homeschooling can please provide',
#   'hopefully we can get #homeschooling #workingfromhome 🤦🏽\u200d♀️',
#   'revitalising! great wake up for what’s life. community, empathy, &amp; enjoying nature &amp; exercise 😊 with cluster fuck #wfh #homeschooling just flip household / workplace upside 🙃'],
#  17: ['gonna beat #wfh by running encouraging each join us keep #covid19 run can 🖖🙌',
#   'been couple hours. be re-stack #wfh #covid19aus',
#   'clear #wfh #covid19'],
#  18: ['37 #workingfromhome green fingers have been rewarded, result lot hard work can finally harvest bounty #coronavirus #covid_19 #cat #catsofinstagram ealing, united kingdom',
#   '42 #workingfromhome hostile happen #cat #catsofinstagram #hostiletakeover #covid_19 #coronavirus ealing, united kingdom',
#   '52 #workingfromhome gone where piglet would napping now windowsill has replaced wonder where noise was coming from #covid_19 #coronavirus #cat…'],
#  19: ['engineer up wi- fi will not fix we coz we need wi- fi right now with #wfh #coronavirus',
#   'what kind providing. connection wifi networks worst... how ppl will continue #wfh with pathetic',
#   'worst ever.. filed complaint 12days back now no resolution for wifi connectivity. #timbl #patheticnetwork #wififailed #wfh'],
#  20: ['work but by 😴☀️ #wfh richmond hill, london',
#   '"hello hr? - like file harrassment work place claim please" #siamesecatsofinstagram #catsofinstagram #workingfromhome #monday london, united kingdom',
#   '#workingfromhome ..? london fields'],
#  21: ['hear ... fit free classes facebook live every wednesday 10am 😯 #wednesdaymotivation #lockdown #facebooklive #freefitness #stayhomesavelives #wfh #exerciseathome #hiit #fitness',
#   'can will. can won’t. power within #bodytransformationchallenge #workingfromhome #homeworkout #onlinetrainer #personaltrainer #jerseycity #nyc #bellyfat…',
#   '#freefitness #facebooklive with weds 10am ... 30mon expresss workout! #getfit #exerciseathome home 💪🏽💪🏻 #fitness #workingfromhome #stayathomesavelives #keepfitathome #london #coronaviruslockdown'],
#  22: ['back #workingfromhome 🤦\u200d♂️🤦\u200d♂️🤦\u200d♂️ #covid19',
#   '#workingfromhome protect from #covid19 not very ergonomic... lucky 🙌',
#   '#workingfromhome #covid19 choices like work'],
#  23: ['have been lot chair behind joins #quarantinecats #wfh #fellowlife',
#   'no will be for creation quarantine, not even new gilliam (1935 - ) renaissance 1986 enamel, canvas wood (in parts) 75 x 90 x 7 #abstract #details #artoftheday #quarantine #wfh #style',
#   '#wfh #quaratinelife #quarantinedkids got conference call went find kids... have lost'],
#  24: ['vs #wfh no longer binary good bad, big changes for #cre. finale #workbold podcast👇🏻',
#   'how lululemon know exactly what need right now? #wfh',
#   '#wfh churn rate based how batteries need changing lot.'],
#  25: ['ultimate working from home chair for under $500 ! london premium ergonomic chair for express wide .... link: #workingremotely #workingfromhome #workfromhome #officechairs #officechair #ergonomicofficechair #ergonomic',
#   'first new job jigsaw puzzle box laptop riser $5 kmart cushion best kitchen chair for 9-5 #wfh. #covid19aus',
#   'chair, rather chair 😁 - harley helped with quality control 💙 #workingfromhome #stayhome #newofficechair #selfassembly bow,…'],
#  26: ['weeks networking wednesday here. exciting news coming up later 📱💻☕️👍🏻 #mrdanielmatthews #networking #networkingwednesday #working #workingfromhome #excitingnews',
#   'well gonna continue networking planning productive positive possibly can be, keep busy can while working from home. #mrdanielmatthews #workingfromhome #lockdown #stayhome #staysafe #bekind',
#   'gonna normal networking wednesday well normal possible under circumstances. focusing networking, promotions. #mrdanielmatthews #networkingwednesday #workingfromhome #staysafe'],
#  27: ['exciting new room “office” - jazzy printer laminator 😍 #workingfromhome',
#   'working new print. #workingfromhome #alternativephotographicprocess #alternativephotography #19thcenturyphotographicprocess #quarentinelife #photography #spirituality #fashionphotography #portraitphotography #saltprint #stayhomesavelives #staysafe',
#   '🚨 wfh update 🚨 ⚡ living life luxury with new laser printer. 🥂 for lawyer level up #wfh'],
#  28: ['#homeoffice #workingfromhome #staysafe #stayhome #nycbear #nybear #beardedengineer #beardofinstagram #bearlife #starwars college point, new',
#   '‘tis good friday. 🙏 #emiliothepapillon🐶 #wfh #wfhbuddy #beardsandtattoos #clubchavez🐾 brooklyn, new',
#   'wondering how new questioning why grinding nyc working from home for long. hard get but know when be back #wfh #nyc'],
#  29: ['partner #husband #isolation #covid19 #torontophoto #photo #toronto #leslieville #riverdale #riverside #theeastside #workingfromhome #mondaymood #monday',
#   'happy #isolation #covid19 #workingfromhome #homeoffice #thursday #thursdayvibes #torontophoto #toronto #leslieville #riverdale #riverside #theeastside riverdale,',
#   'current view, #earlyriser #earlymorning #workingfromhome #tuesday #tuesdayvibes #outdoors #outside riverdale,'],
#  30: ['winners economy worth #business #money #trade #economy #workingfromhome #workfromhome #wfh #work #career #jobs #corporate #office #officedesign #backtowork #amazon #amazonprimeday #zoom #microsoft #slack',
#   'currently #grinding #workingfromhome #marketing #entrepreneurship',
#   '#innovation #entrepreneurship #entrepreneurlife #startup #workflex #flexibleworking #remoteworking #teleworking #workfromhome #wfh #workingfromhome #johnwayne #theduke victoria,'],
#  31: ['working from home #wfh nobody from called . know how required #coronavirusindia',
#   'working from home for next few weeks #wfh #workingfromhome #coronavirus #covid19 #selfisolate #socialdistancing london, united kingdom',
#   'been working from home 7:30am. welcome new normal. #coronavirus #workingfromhome #socialdistancing bronx, new'],
#  32: ['#workingfromhome forget look lovely blue blossom right now. nature constant can keep us grounded. how beaut neighbour’s',
#   'when helps with gardening... . 📸 luitalin . . . #workingfromhome #lifewithlittlemilo #gardening #muddyasf #mud #planting #puppy #cavalierkingcharlesspaniel #puppyoftheday camden',
#   'long enough garden perfect for #workingfromhome'],
#  33: ['please rt great #news #covid19uk #covid19uk #covid2019 #coronavirusoutbreak #coronavirus #corona #newspicks #coronavirusnederland #coronatuerkiye #coronabelgie #coronavirusdeutschland #stayathome #coronabelgie #pmqs #quarantinelife #workingfromhome',
#   'rt because best heard #coronavirus. not just for #irish people but for folks. be far wide #coronavirusoutbreak #covid2019 #covid19 #quarantine #flattenthecurve #stayhome #stayconnected #covid #workingfromhome #stopthespread',
#   'countries begin relax covid-19 restrictions,⚕️ remains precautionary 🔬©️→↓ #science_natural_page #coronavirusupdate #workingfromhome #コロナウイルス #us #covid2019 #safety #safetyfirst #فيروس_كورونا'],
#  34: ['woke up 9:59 work by 10:00. #wfh',
#   'when go wake up 8am but work for 8:30am #workingfromhome',
#   'woke up 6am. work 7:30am. who #wfh #adultlife finally'],
#  35: ['here’s new up working from home. #amnewsers #covid19 #workingfromhome',
#   'finally 12+ weeks working from home from with girls back #workingfromhome #covid19aus',
#   'been working from home. #wfh #covid19'],
#  36: ['wanna be 😭 #wfh', 'but no-one’s 🤔... #wfh', 'wfh 👨\u200d💻 #wfh'],
#  37: ['by 2030, every will be virtual #virtualoffice #smallbiz #startup #smallbusiness #startups #entrepreneur #workfromanywhere #workfromhome #sidehustle #digitalnomad #remotework #growthhacking #businessgrowth #business #b2b #workingfromhome',
#   '#lawyer brick-and-mortal #virtualoffice #smallbiz #workingfromhome #smallbusiness #startups #startup #entrepreneur #business #entrepreneurship #digitalnomad #growthhacking #nyc #bizitalk #lawpractice #attorneys #nyc',
#   'fifth heart rates from $30/mo: #virtualoffice #smallbiz #startup #smallbusiness #startups #entrepreneur #workfromanywhere #workfromhome #startuplife #workingfromhomelife #business #workingfromhome'],
#  38: ['(cold) from balcony. 26 #workingfromhome #viewfrommywindow #garden #plants #quarantinelife #tinybalcony #lockdown #spring #muswellhill #london #uk #nature #rain hill',
#   'back balcony, hours. 13 #workingfromhome #garden #view #tinybalcony #muswellhill #london #uk #trees #window #viewfrommywindow #blossom #bloom #quarantinelife #lockdown',
#   'balcony “springwatch” nature!! 14 #workingfromhome #viewfrommywindow #garden #trees #thenandnow #quarantinelife #tinybalcony #lockdown #spring #muswellhill #london #uk…'],
#  39: ['banksy new works while #wfh 👀',
#   'new kinda #wfh 😎 #magnongroup #egplusww #metalrain #advertising #digital',
#   'new blog post #wfh'],
#  40: ['#resipsa #ourbrandistravel #wfh los california',
#   '#wfh • very helpful • 🖤🖤 west hollywood, california',
#   'wfh . . . #tgif #tiobernie #wfh los california'],
#  41: ['board just few weeks 🤦🏻\u200d♀️ #wfh #coronavirus',
#   'positive with #it-#ites request relax #osp conditions enable #wfh fight #coronaviruspandemic',
#   '.@neiltyson #coronavirus #wfh'],
#  42: ['fantastic #whpc #wfh',
#   'brilliant! watch! #wfh',
#   'nice loubitan. no #wfh'],
#  43: ['weather getting better na from bed we roll enter #wfh',
#   '#sunny &amp; #warm 😌🌅 #wfh not bad when have #sun like rain for work way. 👌 #sun',
#   'live weather forecasts from humble we practice 🏠☀️ first rule #wfh: enjoy cup joe.☕️😌'],
#  44: ['carolyn’s live broadcasting extra fun. #flashbackfriday #freezeframe #workingfromhome #wfh #wfhfails',
#   '#happyfriday🎉🙌😊 cbsn from her home &amp; 2 #staysafestayhealthy💙 #longisland #wfh🏠 #freelive247 #alwayson',
#   'working from home with extreme channeling courtney love circa 2004. when “you”, #90skid #courtneylove #wfh #overit'],
#  45: ['home #wfh',
#   'else worried burning house while #wfh? just',
#   'upgraded home 👍🏼 #advertising #wfh'],
#  46: ['weeelllll....#wfh find balance between high hopes, productivity, external #covidanxiety having breaks 😏',
#   'productive between 5:30 8:30am #focus #wfh #wfhlife #productivity #creativity',
#   "when little brain. but 'deep work' point legit. for who battling with productivity... #wfh #productivity #fuckthedot"],
#  47: ['life #wfh #conferencecall',
#   'nyle’s first conference call. he learned lot, wants be reporter. #workingfromhome perks.',
#   'washed while conference call.. #wfh &gt;&gt;&gt;'],
#  48: ['week 62, bmo pig friends with candle 🐽💜 #londonlife #lifeinthetimeofcorona #workinthetimeofcorona #wfh #candlesofinstagram #pighotel',
#   'week 60, hi, exh! 👋 #londonlife #lifeinthetimeofcorona #workinthetimeofcorona #wfh exchange liverpool london',
#   'week 87, has given bendiness with leg up 😅 #londonlife #lifeinthetimeofcorona #workinthetimeofcorona #wfh #brokenankle #resticecompressionelevation'],
#  49: ['500 hrs far untangling headphones every (about 5 🙄). need face up go wireless #virtualmeetings #wfh #wfhlife',
#   'very $4 products from #dollarama. nice bright ring light clear wired headset. great value for #wfh',
#   'quite possibly best real world why headsets good. u work from home have watch 👀 what 😏 #avtweeps #workingfromhome #makingworkfun #microsoftteams #workfromhome'],
#  50: ['👩🏻\u200d💻 from living room bedroom... up which room productive #workingfromhome #staysafestayhome',
#   "good ... have woman, goes by name living house here ? ... what's ? #workingfromhome ...xx",
#   'his hers. we’ve had rooms before we end up each #workingfromhome #corona waverley, bronte'],
#  51: ['catch joy virtually (and literally) hanging (on googlehangouts ) with friend jaime #perspectives #overcomecovid19 #wfh #tjmandco…',
#   '#backtowork. we r ensuring we #socialdistancing while group photo #backtowork. great be back finally 2.5 #wfh',
#   'human but how have part friend group 5 person? 🤔 #friends #socialbehaviour #humanbeing #connected #wfh #meeting'],
#  52: ['how #wfh by 🤩💯🙌🏻 needed #wellbeingwednesday',
#   'healthy while #workingfromhome',
#   'could benefit from #osteopath, #workingfromhome? her #wfh prudence wade would like explore further? get with us here: . . . #posture'],
#  53: ['need right now? here new podcast with hiam #leadership #covid #wfh #motivationmonday #katietalks',
#   '🚨podcast 🚨 for having episode 4 his podcast “fine we working from home: good, bad embarrassing. listen now by hitting up link below 👇🏻 #podcast #workingfromhome #lifelessons',
#   'never passport listen episode 2 #applepodcasts else listen #podcasts. • • #passport #passportandchill #whileatwork #working #workingfromhome #remotework…'],
#  54: ['\u2063 wednesday love how has personalised her home works for her with gallery wall. #homeoffice\u2063 #wfh\u2063 #interiorinspo \u2063 #officedesign \u2063 #officedecor\u2063 #homeofficdideas\u2063',
#   '#workfromhome (asking for friend) #workingfromhome #homeoffice #selfiewednesday #properattire',
#   'for love &amp; 👏🏼 #workfromhome #wfh #workingfromhome #remotework #homeoffice #wellness #wellbeing'],
#  55: ['15 #selfisolating we’re go bit positive by choosing focus can control. hair! ready welcome 3rd week #wfh with fresh &amp; fun burst colour. #selfcaresunday #stayathome #socialdistancing',
#   'have perks #wfh ~ getting hair everyday, even weekends, pretty big bonus 💅',
#   'when ur #workingfromhome ur waiting for ur coworkers respond.. u realize putting ur hair u feel like 🤣🤣🤣🤣 #boredaf las vegas, las vegas'],
#  56: ['best package! buy now with free #popupdesk #workfromhome #standingdesk #standsitdesk #sitstanddesk #portabledesk #officesolution #wfh #workingfromhome #officesoltutions #desk #homeoffice #studydesk #homeschooling',
#   'best package! buy now with free #popupdesk #workfromhome #standingdesk #standsitdesk #sitstanddesk #portabledesk #officesolution #wfh #workingfromhome #officesoltutions #desk #homeoffice #studydesk #homeschooling',
#   'walnut #table #desk #workingfromhometips #workingfromhome #homeoffice'],
#  57: ['... #dell #india #iwork4dell #appriciationpost #salesopsteam #value #trust #life #2020 #lockdown2020 #wfh #newlife #andrew #rosandra #appriciate #happy #feelsgood #mademyday rosandrafs…',
#   'like famous. . . . #officialsurajgautam #21stcenturyopportunities #oeoentrepreneurs #dress #dressup #dressing #malegrooming #famous #public #publicfigure #page3 #corporate #professional #socialmedia #businessman #youth #youthicon #wfh',
#   'what love. . . . . #officialsurajgautam #21stcenturyopportunities #oeoentrepreneurs #do #what #you #love #model #modeling #digitalentrepreneur #entrepreneurship #public #corporate #socialmedia #businessman #youth #likeforlikes #like4likes #likeforfollow #youthicon #wfh'],
#  58: ['#workingfromhome got like... #coronaviruschallenge',
#   'else feel like cocktail #workingfromhome #coronavirusaustralia',
#   '#workingfromhome #coronavirusaus not how ergonomic have reach new curatorial use'],
#  59: ['else coming with just how noisy neighbours 😳 #wfh',
#   'can name positive #wfh being will no noise cubicle.',
#   'highlight - call with 40 clients &amp; colleagues - client1 giving update we heard child - client1 “sorry just need his zoom parade”...client2 “yes please go...oh barking. #leadership #wfh'],
#  60: ['happy have #covid2019 #stayhomechallenge #workingfromhome #socialdistancing #quarantinelife #withyoutoday #tuesdaymotivation #covid19 #californiacoronavirus',
#   'up email for cc every email #coronavirus #wfh #quarantine #tipoftheday',
#   'hack: has water back for 4.5 &amp; chill. works wonders. pass &amp; links👇 #wednesdaywisdom #workingfromhome #covid19 #quarantinelife #coronaviruschallenge #selfquarantine'],
#  61: ['ultimately by flowers last forever with water... #workingfromhome #wfh #flowers buckhurst hill',
#   'when flowers for brighten up long nights #lovemycolleagues #wfh',
#   'bring #springflowers 💙🏵️ #qotd #wednesdaymorning #lampshade #bluelampshade #orange #flower #orangeflower #homeoffice #workingfromhome #floral #floraldesigns #floraldecor #lightingdesign #detolaandgeek #earlybiz #firsttmaster #ukgiftam'],
#  62: ['everyone #homeoffice #workingfromhome here ☺️',
#   'up for productive #wfh #homeoffice #makinglemonade #doyourbest #tradeshowguy',
#   'update #homeoffice - featuring #raccoon #wfh #wfhlife'],
#  63: ['jumping laptop following from #mrdanielmatthews #workingfromhome',
#   "how's everyone enthusiastic while front laptop like fried bhatoora #mondayblues #workingfromhome",
#   'hdd for record laptop was nightmare upgrade. clips, etc just hdd. #computing #workingfromhome'],
#  64: ['christmas gift for kids. #wfh #wine',
#   'guess we well for now for new normal, but wine bottles come empty full? wish real #wfh wine. well, could, for…',
#   'home right next wine rack - what we call #workfromhome goals! #wfh #homelister new new'],
#  65: ['great for &amp; find #workingfromhome #workingtogether #coronaviruspandemic #congressfightscorona #covidー19 #florida #wednesdaywisdom #teammario #cuomoprimetime',
#   'get journey how why #covidgoals #whencoronavirusisover #wfh #goalsetting #achieveanything #declutter #mondaymorning #mondaythoughts #mondaymotivation',
#   'have lost relevance. working from home #wfh #workingfromhome #mondaythoughts #mondaymotivaton #mondaymorning #covid_19 #covid19 #coronaviruspandemic'],
#  66: ['home work has nothing with paralympics. honest. #morningcommute #workingfromhome #paralympics #busybusy #sport #covid19 #coronavirus #london hampstead, united kingdom',
#   "glad governments uk have grasp positive historical longview, commuting not 'normal'. #covid19 #workingfromhome",
#   'city landan weekday, what pandemic place! #london #cityoflondon #deserted #autumn #winteriscoming #wherearethepeople #workingfromhome #thames east, london'],
#  67: ['#popmaster everyone #bbcradio2 #radio2 everything for pop ! 10:30 for new #workingfromhome',
#   'hi fans. here’s quick update what’s going e radio. #springsteen #siriusxm #radio #rocknroll #socialdistancing #workingfromhome',
#   '#radio for #sundayfunday #sundaymorning with #welovethe90s coming up with loads #radio #kent #workfromhome #wfh #homestudio'],
#  68: ['#wfh cool 😎 #delhirains',
#   '#wfh #testingengineer #softwaretesting #delhincr #manualtesting new',
#   'now #delhi positive case. brace for while get #wfh! #india #lockdown #modi #coronawarriors'],
#  69: ['busy #meetingminutes #workingfromhome #blackprofessionals',
#   'working proofing board #meetingminutes #workingfromhome #wfh #remoteworking #minutetaking #career #blackprofessionals',
#   'having productive working #workingfromhome #wfh #blackprofessionals #career'],
#  70: ['whats #smythsoncollectors by collection here: #smythson #bondstreet #london #leather #collections #obsessions #notebook #desk #wfh',
#   'find notebook literary brilliance (or just here: #smythson #stationery #british #pens #london #mayfair #bondstreet #writing #desk #wfh #leather #paper #notebook',
#   'wait 2022 brochure will be with very up here be first know: #smythson #stationery #diary #smythsondiary #paper #british #pens #london #mayfair #bondstreet #writing #desk #wfh #leather'],
#  71: ['having chilled #wfh needed 😊',
#   'else wearing blanket clothes #wfh #chillyanddamp',
#   '#wfh complained chill well. warm up break. heat not going'],
#  72: ['feeling course by but get #wfh #meetings',
#   'listen #wfh',
#   'been great listening from #wfh #thankyouaaron'],
#  73: ['needed fresh earlier permitted walk! #walpolepark #wfh',
#   'parkfield road walpole road underpass #covid19uk #wfh',
#   'park walks #andbreathe #air #workingfromhome #nofilters ruskin park'],
#  74: ['new working world #workfromhome #wfh #workingfromhome #careers #employment #hr #jobs #corporate #business #money #trade #economy #covidー19 #covid19 #covid2019 #coronavirus #coronavirusoutbreak #coronavirusupdate #usa #us',
#   'last recession gave us gig economy. covid-19 could help reimagine #work #futureofwork #gigeconomy #dignityofwork #wfh #freelance #coronaviruspandemic',
#   'covid-19 pandemic -&gt; wfh -&gt; relocation city centres -&gt; real estate re-distribution -&gt; geographically workforce -&gt; 5-10 from now -&gt; global remote work -&gt; global payment currency -&gt; universal currency?? possible? #covid19 #wfh #crypto'],
#  75: ['#workingfromhome 30: between emails want emails have pray for #quarentine2020 #workingfromhomechronicles #quarentinechronicles',
#   '#workingfromhome 33: grading let emails begin. favorite when email how pass...with zero capital letters punctuation kind. 🤔 #quarentine2020 #workingfromhomechronicles #quarentinechronicles',
#   '#workingfromhome 23: now feels like work what for both work hobby. bored? guess could just work #quarentine2020 #workingfromhomechronicles #quarentinechronicles'],
#  76: ['vía #workingfromhome, remember have #healthysnacks near what go-to healthy forget! exercising home está #workingfromhome, recuerde',
#   '#workingfromhome now normal &amp; permanent #workingenvironment for us. check 9-point guide helping healthy, &amp; ergonomic, whilst working from home. ⠀ for #bespoke #homeofficesolutions, get',
#   'healthy but #wfh coming here’s what 1) bake &amp; freeze (deliver neighbours/colleagues/friends) 2) cook (simmer whilst working, freeze batches) 3) run lunchtime/online workout/yoga practice 4) podcasts -'],
#  77: ['#championsleague 3pm 🔴⚽️🔴⚽️🔴 can closer want👓 #inter v #liverpool 🔴⚽️🔴⚽️🔴⚽️ #brooklyn #soccerbars #workingfromhome #lampshade #lfcbrooklyn #nevergiveup #washyourhands 🍺',
#   '159, europa league 3 - v roma with comms #workingfromhome #womeninfootball',
#   '#nyderby #wfh ⚽️thanks for chatting💻 with for fox5ny 🎮emlsgaming #fifa20 3rd #mls #rbny #nycfc #rivalry #derby #usmnt…'],
#  78: ['great way return 💻 find post note 😊 #isolationlife #workingfromhome #coronavirus #covid19vic',
#   '.@rahuldacunha, #covidindia #workingfromhome #staysafestayhome #coronavirusindia',
#   'boy have #covid2019 #stuckathome #workingfromhome #newyork #coronavirusnyc'],
#  79: ['first #wfh ✅ can’t wait be lonely loser london for foreseeable future! 😅',
#   'why people #driving london?? essential can’t #wfh pple? #pt use w #cars',
#   'when get #wfh harrow, united kingdom'],
#  80: ['working home need nice long list chilled vibes for background we recommend fabulous list, curated by #stayingin #playlist #wfh',
#   'can #wfh get up &amp; every hear billy joel hit playlist! 💃',
#   'construction workers window playing jams right now. just played ‘oye by now ‘gasolina’ by el big boss #workingfromhome'],
#  81: ['“@microsoft by embedding core products, customers will be build comprehensive view global businesses...” #mspartner #wfh',
#   'great from customers, partners, colleagues, employer #microsoft for work we keep everyone &amp; crisis #wfh. very enjoyed #identitydayoff with - first pool 😎',
#   '#wfh like boss. 365 provides favourite #microsoft #microsoftteams &amp; #office365 under roof! #cloud #outlook with ease with visit #100daysofcode #canada'],
#  82: ['beach cherry beach. #wfh #biketo #cyclinglife',
#   'beach busier ever 8am... #workingfromhome #covid_19 #socialisolation #keepcalm #sydneylife #beachsideliving #beachside #lifegoeson #australianlife cronulla beach, new wales,',
#   '#wfh brighton beach'],
#  83: ['forget, burger friday 🍔🎉 rest please email blueroom@hotmail.co.uk 😊 #burgers #burgerfriday #lunch #wfh #fridaytreat #kidsoptions #veganoptions #se4 #brockley #croftonpark #catford #honoroakpark #lewisham #shoplocal',
#   'we’re back from with weekday lunches, boxes popular jerk lunch. feb 😋 #se4 #croftonpark #brockley #lewisham #february #lunch #wfh #shoplocal #supportlocal',
#   'weeks lunch bbq pulled leg homemade brioche bun, with potato fries &amp; jalapeño coleslaw. priced just £5.95 blueroom@hotmail.co.uk #se4 #croftonpark #brockley #lunch #wfh #shoplocal #supportsmallbusiness'],
#  84: ['further burdening class for working perfect god forbid considers rich...or banks. perhaps for bail us huh? 😡 ps, $55k #nyc poverty level! #howdareyou #wfhtax #wfh #hypocrites',
#   '#wfh portion home used hired by employer. employee not be paid for ? #ceo #hr #jobs #layoffs #salary #salarycut',
#   'going have hell fill #workingfromhome #wfh #canarywharf group lodges latest plans for large new #property #officespace'],
#  85: ['🌼 roscoe village neighborhood #chicago #roscoevillage #design #designinspiration #designthinking #chicagorealestate #chicagorealtor #roscoevillagerealestate #stayhome #roscoevillagechicago #architecture #roscoevillagerealtor #workingfromhome #rain',
#   'helping... . . . #wfh #bigblackcat #rockythekitty #catsofinstagram #helperkitty rogers park, chicago',
#   '#workfromhome #workingfromhome #pomsky #fiance uptown, chicago'],
#  86: ['#bandtee by favourite groups gunsnroses upset not being #concert #wfh #ootd west queen west',
#   '#wfh #ootd brought by lululemon #rockinroll queen west',
#   '#wfh #bandtee 90’s classic nirvana #ootd'],
#  87: ['#office : post-apocalypse - gloom full-bloom. #workingfromhome #remotework #nj',
#   'following #sunsoutgunsout #babyoilondeck #workingfromhome east rutherford, new jersey',
#   '#wfh getting control (swipe 👉) jersey city, new jersey'],
#  88: ['logged from laundry room: how c.e.o.s google, pfizer work from home #workingfromhome #workfromhome #wfh #work #career #business #money #google #pfizer #slack #zoom #siliconvalley #stayathomeandstaysafe #coronaupdate #covid_19',
#   'working from home? boss watching. #workingfromhome #workfromhome #wfh #work #career #business #money #trade #economy #zoommeeting #slack #microsoft #mondaymorning #mondaymood #covidー19 #covid19 #covid2019 #coronavirus #coronavirusoutbreak',
#   'logged from laundry room: how c.e.o.s google, pfizer work from home #workingfromhome #workfromhome #wfh #work #career #business #money #google #pfizer #slack #zoom #siliconvalley #stayathomeandstaysafe #coronaupdate #covid_19'],
#  89: ['parenting working plausible! #wfh #parenting',
#   '- father #puzzle rule - has find/make puzzle which her #mensa father cannot 3 can her him for 3 #excited. let’s who wins who convinces 😂. #wfh',
#   'where #wfh parents? read 👇👇👇 via'],
#  90: ['❣️ up for #festive fun virtual #christmasparty 🌟🎄🎈 #wfh #workingfromhome #workchristmasparty london, united kingdom',
#   '#wfh #festiveseason ? #comment for visit handle',
#   '❣️ up for #festive fun virtual #christmasparty 🌟🎄🎈 #wfh #workingfromhome #workchristmasparty london, united kingdom'],
#  91: ['lunch walks .. who knew was local #parramattapark #westmead #flowers #nature #governorphillipwalk #exercise #relax #wfh #nature #spring #sydney 🌼🌺🌸🦎🦆 governer phillip walking',
#   'went for early bit exercise #powerwalking #running quite humid #sydney wanted get before georges river lga curfew 9pm work we have flexible working hours &amp; #workingfromhome',
#   'colours 🍂 🍁🍂 #lunchwalk #wfh #parramatta #local #fallenleaves #autumn #sydney #australia #beautyofnature 📸 cybershot parramatta park'],
#  92: ['be #wfh',
#   '#wfh be like.... #got',
#   '#wfh has never been when comes back #wholenewgame coming 💪🏾💪🏾💪🏾'],
#  93: ['good #communication #skill. presentations #publicspeaking can be guide let feel control. #teaching #vocaltechnique #workingfromhome',
#   'working from home. how record voice for #tvnews #wfh',
#   'ever experience hurt vocal cord profession ? #workingfromhome #workathome #voice'],
#  94: ['jpmorgan will have cycle between remote work #jpmorgan #goldmansachs #hsbc #newyork #wallstreet #financialservices #financialmarkets #business #money #london #corporate #workingfromhome #workfromhome #wfh #career',
#   "goldman bank boss rejects work from home 'new normal' #workfromhome #wfh #work #career #jobs #corporate #office #officedesign #backtowork #workingfromhome #goldmansachs #london #city #canarywharf #pandemic #coronavirus #coronavirusoutbreak",
#   '(“interior kitchen” #ealing #westlondon based financial journalist #behindthescenes #workingfromhome presenting “secrets business journalism” lecture for #kyivschoolofeconomics #ukraine 🇺🇦'],
#  95: ['remote work up geopolitics #workingfromhome #workfromhome #wfh #work #career #jobs #corporate #office #remoteworking #remotework #china #xijinping #asia #europe #eu #europeanunion #business #money #trade #economy',
#   '#thegreatresignation #remotework was paradise, everyone working from home via #nimby #realestate #zoomboom #eattherich #co #colorado #crestedbutte #altitudetraining #wfh #workfromanywhere #workfromhome',
#   'remote work here never be #workfromhome #wfh #work #career #jobs #corporate #office #officedesign #backtowork #workingfromhome #newyorkcity #newyork #ny #nyc #brooklyn #manhattan #london #city #canarywharf #business'],
#  96: ['wallpaper game be #wfh',
#   'background rather crunching #wfh',
#   'wallpaper game be #wfh'],
#  97: ['fourth week working from home. here coworkers 😄🥰 #wfh #quarantine #fourweeks #fiftyeightpost #rescue new jersey',
#   'working from home february has like 🤦🏽\u200d♂️ #quarantine #workingfromhome',
#   'friend complaining bear being while work/school from home! 🤣 #california #pandemic #quarantine #homeschool #virtuallearning #wfh #problems'],
#  98: ['"4 critical #remotework covid-19 pandemic" via #wfh',
#   'finally #team get #f2f 15months excellent remote working 😊 💻 #wfh #nhsltp. love for we from #covid 😩but was (&amp; virtually, course 💁🏽\u200d♀️)❤️🦷',
#   ':o 🤷🏼\u200d♂️🤦\u200d♂️ which part #covid19 get? #wfh #remotework.'],
#  99: ['working hours 9-5 however been logged #microsoftteams emails care few hardly ever got lol. working patterns blurred 🙃 #workingfromhome #work',
#   'just received email “maddy, we need had heart-attack. was personal email. from wine loyal customers weekday working hours? 😥 #wfh #consultantlife',
#   'just received email clear (i was lucky have context preparation facilities for gradual work 30 rock. good bad news, 🤷 ? #wfh'],
#  100: ['#contestalert best like #wfh get with family.. #giveaway #wfhperks #gadgetgiveaway. join',
#   'check #instagram #giveaway for #free #coworking #daypass #clickhere - #wfh #scarborough #contest #wexford #community #win #supportlocal #win #prizes #nomoneydown',
#   '🤘🏻 #wfh #deskgiveaway #giveaway #brownelephantfurniture #contestalert'],
#  101: ['power parts heatwave. no power vasant kunj 11:00 pm #poweroutage #noelectricity #wfh #heatwave #heatwarning',
#   'love #workingfromhome heatwave.',
#   'working gloom with fan because no work would get #wfh #workingfromhome #survivethisheat #heatwaveuk #hotaugust'],
#  102: ['can’t wait for rush hour commute back #wfh casualties',
#   'excited full #wfh have returned perennially #nyc commute. last!',
#   'was pretty emotional return neighborhood left 8 weeks ... no return before #wfh #nypause #nyclockdown'],
#  103: ['planning for week like learn #powerbi week, join us 30 for 3 hour beginners class via zoom #powerbi how create reports people will want read! link bio book #wfh',
#   'join us for #beginners #powerbi 30 via zoom. 3 hour class 9.30am. leave feeling ready needs! book #wfh #learnonline',
#   'ct week, #powerbi .. join us for 3 hours live beginners will leave feeling confident excited use #powerbi work... no boring reports! book place! #wfh'],
#  104: ['commute ghost #wfh',
#   '#wfh has really changed how listen commute',
#   'replacing commute with 15 🥳 #wfh #isolationessentials #motiongraphics']}

# %% [markdown]
# # **Topic Modeling**
#
# In this example, we will go through the main components of BERTopic and the steps necessary to create a strong topic model.

# %% [markdown]
# ## Extracting Topics
# After fitting our model, we can start by looking at the results. Typically, we look at the most frequent topics first as they best represent the collection of documents.

# %%
freq = topic_model.get_topic_info();
freq.to_csv("/content/drive/MyDrive/6000k/nostopword/freq_"+location+".csv")

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('workingfromhome', 0.029300925531527175),
#  ('love', 0.01511942184608348),
#  ('great', 0.011829098594606346),
#  ('back', 0.010313766264378096),
#  ('but', 0.009609868614902088),
#  ('work', 0.009599957510897353),
#  ('been', 0.009562019243632395),
#  ('not', 0.009053650692543947),
#  ('for', 0.008801260952392349),
#  ('know', 0.008669840271592144)]

# %% [markdown]
# **NOTE**: BERTopic is stocastich which mmeans that the topics might differ across runs. This is mostly due to the stocastisch nature of UMAP.

# %% [markdown]
# # **Visualization**
# There are several visualization options available in BERTopic, namely the visualization of topics, probabilities and topics over time. Topic modeling is, to a certain extent, quite subjective. Visualizations help understand the topics that were created.

# %% [markdown]
# ## Visualize Terms
#
# We can visualize the selected terms for a few topics by creating bar charts out of the c-TF-IDF scores for each topic representation. Insights can be gained from the relative c-TF-IDF scores between and within topics. Moreover, you can easily compare topic representations to each other.

# %%
b = topic_model.visualize_barchart(top_n_topics=12)

b.update_layout(
    autosize=False,
    title=("Topics Word Scores"+" ("+location+")"),
)
b.show()
b.write_image("/content/drive/MyDrive/6000k/nostopword/"+"topic_word_scores_"+location+".png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="422f83c2-9f38-44c1-bfd3-1a74f4c1ad79" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("422f83c2-9f38-44c1-bfd3-1a74f4c1ad79")) {                    Plotly.newPlot(                        "422f83c2-9f38-44c1-bfd3-1a74f4c1ad79",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.009848283295513582,0.010131620646245938,0.01032347087478174,0.010360125991437907,0.03126227017185265],"y":["not  ","for  ","when  ","love  ","workingfromhome  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.021657438230508315,0.023314227383816992,0.0299199896989068,0.030478605254695694,0.04167770767796266],"y":["pets  ","dogs  ","catsoftwitter  ","cats  ","cat  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01915635005773789,0.019262521584611458,0.021031318003571043,0.02401262634435486,0.059086809327616174],"y":["food  ","lunchtime  ","chocolate  ","breakfast  ","lunch  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.020474421315098697,0.02499367591552454,0.02541113888359141,0.03020560876604297,0.042067492158350095],"y":["style  ","wear  ","wearing  ","pants  ","fashion  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.013153353774775884,0.014170352879002064,0.015159281225678568,0.016587604038300386,0.02307706941865768],"y":["who  ","work  ","wfh  ","colleague  ","colleagues  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.01593727804817068,0.016881485475722827,0.017398326179070018,0.018236130506195592,0.11328738883526088],"y":["zoommeeting  ","calls  ","call  ","zooms  ","zoom  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013936824586856147,0.014606913835166779,0.017509914493395316,0.022904464707814622,0.13499048293213453],"y":["coffeebreak  ","espresso  ","nespresso  ","cup  ","coffee  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0124103062973851,0.013437248338082452,0.019513663300714554,0.02218933150695931,0.07196032855808866],"y":["lockdownnow  ","wfh  ","lockdownuk  ","lockdown2020  ","lockdown  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.016656933312997335,0.026010069687730134,0.030843926668035454,0.05729850382249845,0.07697548850540807],"y":["remotelearning  ","remotely  ","remoteworking  ","remotework  ","remote  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01529185449532788,0.016489019475413005,0.03141926412619522,0.03753578430575283,0.03926196483461528],"y":["workingfromhome  ","work  ","from  ","working  ","home  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.022743632400448018,0.025817629179355775,0.027619194539165656,0.027619194539165656,0.04536941755129843],"y":["lil  ","nom  ","kevin  ","naavah  ","wfh  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01753389755189394,0.0187547074580053,0.029702290973803662,0.0335281981189426,0.08479382967709066],"y":["call  ","recording  ","webcam  ","camera  ","video  "],"type":"bar","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":" ...

# %% [markdown]
# # **Search Topics**
# After having trained our model, we can use `find_topics` to search for topics that are similar
# to an input search_term. Here, we are going to be searching for topics that closely relate the
# search term "vehicle". Then, we extract the most similar topic and check the results:

# %%
similar_topics, similarity = topic_model.find_topics("food", top_n=5); similar_topics
# Out:
# [2, 8, 6, 56, 13]

# %%
topic_model.get_topic(2)
# Out:
# [('lunch', 0.024133588349627234),
#  ('breakfast', 0.012646975841215647),
#  ('and', 0.012146086839072165),
#  ('wfh', 0.011439243673503848),
#  ('with', 0.010594776200100733),
#  ('for', 0.010390998875604934),
#  ('of', 0.009669050194786857),
#  ('food', 0.009576746430649097),
#  ('the', 0.00922208200266935),
#  ('to', 0.008955122393540241)]

# %% [markdown]
# # **Model serialization**
# The model and its internal settings can easily be saved. Note that the documents and embeddings will not be saved. However, UMAP and HDBSCAN will be saved.

# %%
# Save model
topic_model.save("/content/drive/MyDrive/6000k/my_model")

# %%
# Load model
my_model = BERTopic.load("/content/drive/MyDrive/6000k/my_model")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-73397dc292c7> in <module>()
#       1 # Load model
# ----> 2 my_model = BERTopic.load("my_model")
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_bertopic.py in load(cls, path, embedding_model)
#    1313                 topic_model.embedding_model = select_backend(embedding_model)
#    1314             else:
# -> 1315                 topic_model = joblib.load(file)
#    1316             return topic_model
#    1317
#
# /usr/local/lib/python3.7/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     575         filename = getattr(fobj, 'name', '')
#     576         with _read_fileobject(fobj, filename, mmap_mode) as fobj:
# --> 577             obj = _unpickle(fobj)
#     578     else:
#     579         with open(filename, 'rb') as f:
#
# /usr/local/lib/python3.7/dist-packages/joblib/numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     504     obj = None
#     505     try:
# --> 506         obj = unpickler.load()
#     507         if unpickler.compat_mode:
#     508             warnings.warn("The file '%s' has been generated with a "
#
# /usr/lib/python3.7/pickle.py in load(self)
#    1086                     raise EOFError
#    1087                 assert isinstance(key, bytes_types)
# -> 1088                 dispatch[key[0]](self)
#    1089         except _Stop as stopinst:
#    1090             return stopinst.value
#
# /usr/local/lib/python3.7/dist-packages/joblib/numpy_pickle.py in load_build(self)
#     329         NDArrayWrapper is used for backward compatibility with joblib <= 0.9.
#     330         """
# --> 331         Unpickler.load_build(self)
#     332
#     333         # For backward compatibility, we support NDArrayWrapper objects.
#
# /usr/lib/python3.7/pickle.py in load_build(self)
#    1550         setstate = getattr(inst, "__setstate__", None)
#    1551         if setstate is not None:
# -> 1552             setstate(state)
#    1553             return
#    1554         slotstate = None
#
# /usr/local/lib/python3.7/dist-packages/pynndescent/pynndescent_.py in __setstate__(self, d)
#     936             self._init_sparse_search_function()
#     937         else:
# --> 938             self._init_search_function()
#     939
#     940     def _init_search_graph(self):
#
# /usr/local/lib/python3.7/dist-packages/pynndescent/pynndescent_.py in _init_search_function(self)
#    1324         query_data = self._raw_data[:1]
#    1325         inds, dists, _ = self._search_function(
# -> 1326             query_data, 5, 0.0, self._visited, self.search_rng_state
#    1327         )
#    1328         _ = self._deheap_function(inds, dists)
#
# /usr/local/lib/python3.7/dist-packages/numba/core/dispatcher.py in _compile_for_args(self, *args, **kws)
#     365                 argtypes.append(self.typeof_pyval(a))
#     366         try:
# --> 367             return self.compile(tuple(argtypes))
#     368         except errors.ForceLiteralArg as e:
#     369             # Received request for compiler re-entry with the list of arguments
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# /usr/local/lib/python3.7/dist-packages/numba/core/dispatcher.py in compile(self, sig)
#     817             self._cache_misses[sig] += 1
#     818             try:
# --> 819                 cres = self._compiler.compile(args, return_type)
#     820             except errors.ForceLiteralArg as e:
#     821                 def folded(args, kws):
#
# /usr/local/lib/python3.7/dist-packages/numba/core/dispatcher.py in compile(self, args, return_type)
#      76
#      77     def compile(self, args, return_type):
# ---> 78         status, retval = self._compile_cached(args, return_type)
#      79         if status:
#      80             return retval
#
# /usr/local/lib/python3.7/dist-packages/numba/core/dispatcher.py in _compile_cached(self, args, return_type)
#      90
#      91         try:
# ---> 92             retval = self._compile_core(args, return_type)
#      93         except errors.TypingError as e:
#      94             self._failed_cache[key] = e
#
# /usr/local/lib/python3.7/dist-packages/numba/core/dispatcher.py in _compile_core(self, args, return_type)
#     108                                       args=args, return_type=return_type,
#     109                                       flags=flags, locals=self.locals,
# --> 110                                       pipeline_class=self.pipeline_class)
#     111         # Check typing error if object mode is used
#     112         if cres.typing_error is not None and not flags.enable_pyobject:
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     625     pipeline = pipeline_class(typingctx, targetctx, library,
#     626                               args, return_type, flags, locals)
# --> 627     return pipeline.compile_extra(func)
#     628
#     629
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler.py in compile_extra(self, func)
#     361         self.state.lifted = ()
#     362         self.state.lifted_from = None
# --> 363         return self._compile_bytecode()
#     364
#     365     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler.py in _compile_bytecode(self)
#     423         """
#     424         assert self.state.func_ir is None
# --> 425         return self._compile_core()
#     426
#     427     def _compile_ir(self):
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler.py in _compile_core(self)
#     394             res = None
#     395             try:
# --> 396                 pm.run(self.state)
#     397                 if self.state.cr is not None:
#     398                     break
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler_machinery.py in run(self, state)
#     330                 pass_inst = _pass_registry.get(pss).pass_inst
#     331                 if isinstance(pass_inst, CompilerPass):
# --> 332                     self._runPass(idx, pass_inst, state)
#     333                 else:
#     334                     raise BaseException("Legacy pass in use")
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler_machinery.py in _runPass(self, index, pss, internal_state)
#     289             mutated |= check(pss.run_initialization, internal_state)
#     290         with SimpleTimer() as pass_time:
# --> 291             mutated |= check(pss.run_pass, internal_state)
#     292         with SimpleTimer() as finalize_time:
#     293             mutated |= check(pss.run_finalizer, internal_state)
#
# /usr/local/lib/python3.7/dist-packages/numba/core/compiler_machinery.py in check(func, compiler_state)
#     262
#     263         def check(func, compiler_state):
# --> 264             mangled = func(compiler_state)
#     265             if mangled not in (True, False):
#     266                 msg = ("CompilerPass implementations should return True/False. "
#
# /usr/local/lib/python3.7/dist-packages/numba/core/typed_passes.py in run_pass(self, state)
#     224         pp.run(True)
#     225         with fallback_context(state, msg):
# --> 226             rewrites.rewrite_registry.apply('after-inference', state)
#     227         pp.remove_dels()
#     228         return True
#
# /usr/local/lib/python3.7/dist-packages/numba/core/rewrites/registry.py in apply(self, kind, state)
#      66                 key, block = work_list.pop()
#      67                 matches = rewrite.match(state.func_ir, block, state.typemap,
# ---> 68                                         state.calltypes)
#      69                 if matches:
#      70                     if config.DEBUG or config.DUMP_IR:
#
# /usr/local/lib/python3.7/dist-packages/numba/core/inline_closurecall.py in match(self, func_ir, block, typemap, calltypes)
#    1304         self.crnt_block = block
#    1305         self.new_body = guard(_inline_const_arraycall, block, func_ir,
# -> 1306                               self.typingctx, typemap, calltypes)
#    1307         return self.new_body is not None
#    1308
#
# /usr/local/lib/python3.7/dist-packages/numba/core/ir_utils.py in guard(func, *args, **kwargs)
#    1448     """
#    1449     try:
# -> 1450         return func(*args, **kwargs)
#    1451     except GuardException:
#    1452         return None
#
# /usr/local/lib/python3.7/dist-packages/numba/core/inline_closurecall.py in _inline_const_arraycall(block, func_ir, context, typemap, calltypes)
#    1510         # call, then we must call off the translation for this list because
#    1511         # it could be mutated and list_items would no longer be applicable.
# -> 1512         if state.list_var_used(inst):
#    1513             state.reset()
#    1514
#
# /usr/local/lib/python3.7/dist-packages/numba/core/inline_closurecall.py in list_var_used(self, inst)
#    1451             build_list and the array call.
#    1452             """
# -> 1453             return any([x.name in self.list_vars for x in inst.list_vars()])
#    1454
#    1455     state = State()
#
# /usr/local/lib/python3.7/dist-packages/numba/core/ir.py in list_vars(self)
#     345
#     346     def list_vars(self):
# --> 347         return self._rec_list_vars(self.__dict__)
#     348
#     349
#
# /usr/local/lib/python3.7/dist-packages/numba/core/ir.py in _rec_list_vars(self, val)
#     319         elif isinstance(val, Inst):
#     320             return val.list_vars()
# --> 321         elif isinstance(val, (list, tuple)):
#     322             lst = []
#     323             for v in val:
#
# KeyboardInterrupt:

# %% [markdown]
# # **Embedding Models**
# The parameter `embedding_model` takes in a string pointing to a sentence-transformers model, a SentenceTransformer, or a Flair DocumentEmbedding model.

# %% [markdown]
# ## Sentence-Transformers
# You can select any model from sentence-transformers here and pass it through BERTopic with embedding_model:

# %%
topic_model = BERTopic(embedding_model="xlm-r-bert-base-nli-stsb-mean-tokens")

# %% [markdown]
# Or select a SentenceTransformer model with your own parameters:

# %%
from sentence_transformers import SentenceTransformer

sentence_model = SentenceTransformer("distilbert-base-nli-mean-tokens", device="cpu")
topic_model = BERTopic(embedding_model=sentence_model, verbose=True)

# %% [markdown]
# Click [here](https://www.sbert.net/docs/pretrained_models.html) for a list of supported sentence transformers models.
